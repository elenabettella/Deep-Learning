# %% [markdown]
# #HW5: Autoencoders
#
# In this homework, we will explore how to develop a simple Autoencoder. As a dataset, we will use the MNIST dataset. It contains handwritten digits images.
# In the first part, we will learn how to develop a simple shallow autoencoder, then we will develop a deep version. Next, we will experiment with the application of autoencoder on denoising data task (denoising-autoencoder). Finally, we will apply this model to sequential domains, considering the IMDB dataset, already used in HW4.

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ###Load Dataset
# We load the MNIST dataset, using tf.keras.datasets. The dataset contains 60,000 training images and 10,000 testing images.
# The value of each pixel is between 0 and 255, and it represents a point of an image of size 28 x 28. We will normalize all values between 0 and 1, and we will flatten the 28x28 images into vectors of size 784.
# Finally, since no validation set is defined, we split the test set in a validation set and a new test set.

# %%
(x_train, _), (x_test, _) = tf.keras.datasets.mnist.load_data()

x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255


x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

x_valid = x_train[:10000]
x_train = x_train[10000:]

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.1: Singular Value Decomposition
#
# Principal component analysis (PCA) and singular value decomposition (SVD) are both classical linear dimensionality reduction methods that attempt to find linear combinations of features in the original high dimensional data matrix to construct a meaningful representation of the dataset.
# In this first part of the HW, we will focus our attention on SVD decomposition, a numerical stable method. Given a matrix X, the SVD decomposes it into the product of two unitary matrices V and U and a rectangular diagonal matrix of singular values S:
#
# $$ X=V \cdot S \cdot U^T.$$
#
# SVD is already implemented in NumPy as np.linalg.svd. In our case, the X matrix will represent the training set, where each row is a sample (therefore the number of columns will be the number of input features).
#
# Note that, the X matrix in our case will have a huge number of rows (we have 50000 input samples) and only 784 columns. Therefore to optime the memory consumption, we can compute the SVD of the covariance matrix. An interesting property of the SVD is that we compute the decomposition of the covariance matrix $C= X^T \cdot X$, and we will obtain the following decomposition:
#
# $$ C= U \cdot S^2 \cdot U^T$$
#
# Since we need just the matrix U to compute the compressed version of our data, this method will be very convenient. If you are using the collab free plan, the quantity of available ram is not sufficient to compute the SVD of X, therefore computing the SVD of the covariance matrix turns out to be the best solution.

# %%
def svd_k(X, k):
  # Compute covariance matrix
  C = np.dot(X.T, X)
  # SVD decomposition
  U, s_sqr, U_T = np.linalg.svd(C, full_matrices=False)
  # Limit the number columns of U to k
  U_k=U[:,:k]
  return U_k

# %% [markdown]
# Let's define the ENCODING_DIM, that will be the size of the compressed version of input data. And compute the compressed version of the training set and the test set.
#
# **[TO COMPLETE]**: What happens varying the ENCODING_DIM? test  and discuss the results in a new cell after the following one.

# %%
ENCODING_DIM = 120

U_k=svd_k(x_train, ENCODING_DIM)

x_training_pca = np.dot(x_train, U_k)
x_test_pca = np.dot(x_test, U_k)

# %% [markdown]
# I tested various value of ENCODING_DIM. Starting with ENCODING_DIM=1 the reconstructed input is composed of the same image repeated, so numbers are not distinguishable. With ENCODING_DIM=50 the recostructed images are blurred but numbers are quite distinguishable. With ENCODING_DIM=200 it doesn't change too much with respect to 120. With the latter the backgroung is a bit blurred but the details of numbers are very similar.

# %% [markdown]
# Reconstruct the input and check how much information was lost due to the compression, by computing the mean squared error between the original input and the reconstruction, and by plotting the reconstructed images.

# %%
x_training_reco= np.dot(x_training_pca, U_k.T)
x_test_reco= np.dot(x_test_pca, U_k.T)

# %%
accuracy_train = ((x_train - x_training_reco)**2).mean()
accuracy_test = ((x_test - x_test_reco)**2).mean()

print("training mse: %.5f" % ( accuracy_train))
print("test mse: %.5f" % ( accuracy_test))
# Out:
# training mse: 0.00464
# test mse: 0.00455

# %%
def plot_img(n, input_data, decoded_imgs):
  plt.figure(figsize=(20, 4))
  for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(input_data[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
  plt.show()

# %% [markdown]
# Let's check how well the input can be reconstructed by printing a few of the input images and the corresponding reconstructions. Obviously, all these evaluations have to be done on the test set.
#
# The first row of shown images corresponds to input data, while the second one contains the reconstructions.

# %%
plot_img(10, x_test, x_test_reco)

# %% [markdown]
# ## [TO COMPLETE] Exercise 5.2: Shallow Linear Autoencoder
# Let's define a model that consists of a single fully-connected neural layer. The hidden layer and the output layer act as the encoder and the decoder, respectively. Differently than the previous homework, instead of using Keras.Sequential(), we define the various part of the model (encoder and decoder) separately and then we create the final model.
#
# **[TO COMPLETE]** check the results and compare them versus the results obtained with the SVD. Add a cell  at the end of this section (after the result of the linear autoencoder) where you give an explanation of the relation between the results obtained  by the shallow linear autoencoder and the ones obtained by the SVD decomposition.

# %%
ENCODING_DIM = 120

input_img = tf.keras.layers.Input(shape=(784,))
#Define the encoder...
encoded = tf.keras.layers.Dense(ENCODING_DIM, activation='linear')(input_img)

#...and the decoder...
decoded = tf.keras.layers.Dense(784, activation='linear')(encoded)

#and finally the autoencoder
autoencoder = tf.keras.models.Model(input_img, decoded)

# In order to visualize the learned encoding, define a model that computes the 
# two parts separately.
encoder = tf.keras.models.Model(input_img, encoded)
encoded_input = tf.keras.layers.Input(shape=(ENCODING_DIM,))
decoder_layer = autoencoder.layers[-1]
decoder = tf.keras.models.Model(encoded_input, decoder_layer(encoded_input))

#Finally, let's call the compile method
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), loss='mse')

# %% [markdown]
# Print the model summary.

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense (Dense)                (None, 120)               94200
# _________________________________________________________________
# dense_1 (Dense)              (None, 784)               94864
# =================================================================
# Total params: 189,064
# Trainable params: 189,064
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model.

# %%
history = autoencoder.fit(x_train, x_train, epochs=15, batch_size=512, shuffle=True, validation_data=(x_valid, x_valid))
# Out:
# Epoch 1/15
# 98/98 [==============================] - 2s 14ms/step - loss: 0.0413 - val_loss: 0.0143
# Epoch 2/15
# 98/98 [==============================] - 1s 13ms/step - loss: 0.0120 - val_loss: 0.0087
# Epoch 3/15
# 98/98 [==============================] - 1s 13ms/step - loss: 0.0077 - val_loss: 0.0069
# Epoch 4/15
# 98/98 [==============================] - 1s 13ms/step - loss: 0.0065 - val_loss: 0.0061
# Epoch 5/15
# 98/98 [==============================] - 1s 13ms/step - loss: 0.0066 - val_loss: 0.0061
# Epoch 6/15
# 98/98 [==============================] - 1s 13ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 7/15
# 98/98 [==============================] - 1s 13ms/step - loss: 0.0053 - val_loss: 0.0052
# Epoch 8/15
# 98/98 [==============================] - 1s 13ms/step - loss: 0.0052 - val_loss: 0.0051
# Epoch 9/15
# 98/98 [==============================] - 1s 12ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 10/15
# 98/98 [==============================] - 1s 13ms/step - loss: 0.0050 - val_loss: 0.0050
# Epoch 11/15
# 98/98 [==============================] - 1s 13ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 12/15
# 98/98 [==============================] - 1s 12ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 13/15
# 98/98 [==============================] - 1s 13ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 14/15
# 98/98 [==============================] - 1s 13ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 15/15
# 98/98 [==============================] - 1s 12ms/step - loss: 0.0053 - val_loss: 0.0050

# %% [markdown]
# Plot the loss and the accuracy curves on the validation set, and the accuracy on the test set.

# %%
def plot_loss(history):
  plt.figure(figsize=(10,6))
  plt.plot(history.epoch,history.history['loss'])
  plt.plot(history.epoch,history.history['val_loss'])
  plt.title('loss')

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test, x_test, verbose=2)
print("test mse: %.5f" % (scores))
# Out:
# 313/313 - 0s - loss: 0.0049
# test mse: 0.00491

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

plot_img(10, x_test, decoded_imgs)

# %% [markdown]
# SVD test mse: 0.00455
#
# Shallow linear autoencoders test mse: 0.00491
#
# Both the resulted images and the mse are very similar. This is due to the fact that these two methods are theoretically equivalent. The optimization routine is different (one-step vs gradient descent)

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.3: Shallow non-linear autoencoders
#
# **[TO COMPLETE]** replicate the code of Exercise 5.2 but in this case, instead of using linear activation functions use  non-linear ones. Choose the most appropriate non-linear function, and motivate your choice. Then discuss the results in relation to those obtained in Exercise 5.2. (Insert your code and  theoretical discussion into  cells immediately below this one.)

# %%
ENCODING_DIM = 120

input_img = tf.keras.layers.Input(shape=(784,))
#Define the encoder...
encoded = tf.keras.layers.Dense(ENCODING_DIM, activation='relu')(input_img)

#...and the decoder...
decoded = tf.keras.layers.Dense(784, activation='sigmoid')(encoded)

#and finally the autoencoder
autoencoder = tf.keras.models.Model(input_img, decoded)

# In order to visualize the learned encoding, define a model that computes the 
# two parts separately.
encoder = tf.keras.models.Model(input_img, encoded)
encoded_input = tf.keras.layers.Input(shape=(ENCODING_DIM,))
decoder_layer = autoencoder.layers[-1]
decoder = tf.keras.models.Model(encoded_input, decoder_layer(encoded_input))

#Finally, let's call the compile method
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), loss='mse')

autoencoder.summary()

history = autoencoder.fit(x_train, x_train, epochs=15, batch_size=512, shuffle=True, validation_data=(x_valid, x_valid))

plot_loss(history)

scores = autoencoder.evaluate(x_test, x_test, verbose=2)
print("test mse: %.5f" % (scores))

encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

plot_img(10, x_test, decoded_imgs)
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 120)               94200
# _________________________________________________________________
# dense_3 (Dense)              (None, 784)               94864
# =================================================================
# Total params: 189,064
# Trainable params: 189,064
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 98/98 [==============================] - 2s 17ms/step - loss: 0.0475 - val_loss: 0.0294
# Epoch 2/15
# 98/98 [==============================] - 1s 15ms/step - loss: 0.0255 - val_loss: 0.0224
# Epoch 3/15
# 98/98 [==============================] - 1s 14ms/step - loss: 0.0216 - val_loss: 0.0205
# Epoch 4/15
# 98/98 [==============================] - 1s 14ms/step - loss: 0.0201 - val_loss: 0.0196
# Epoch 5/15
# 98/98 [==============================] - 1s 14ms/step - loss: 0.0195 - val_loss: 0.0190
# Epoch 6/15
# 98/98 [==============================] - 1s 14ms/step - loss: 0.0189 - val_loss: 0.0187
# Epoch 7/15
# 98/98 [==============================] - 1s 14ms/step - loss: 0.0187 - val_loss: 0.0184
# Epoch 8/15
# 98/98 [==============================] - 1s 14ms/step - loss: 0.0185 - val_loss: 0.0183
# Epoch 9/15
# 98/98 [==============================] - 1s 14ms/step - loss: 0.0184 - val_loss: 0.0182
# Epoch 10/15
# 98/98 [==============================] - 1s 14ms/step - loss: 0.0183 - val_loss: 0.0181
# Epoch 11/15
# 98/98 [==============================] - 1s 14ms/step - loss: 0.0180 - val_loss: 0.0179
# Epoch 12/15
# 98/98 [==============================] - 1s 14ms/step - loss: 0.0180 - val_loss: 0.0179
# Epoch 13/15
# 98/98 [==============================] - 1s 14ms/step - loss: 0.0180 - val_loss: 0.0179
# Epoch 14/15
# 98/98 [==============================] - 1s 14ms/step - loss: 0.0179 - val_loss: 0.0178
# Epoch 15/15
# 98/98 [==============================] - 1s 14ms/step - loss: 0.0179 - val_loss: 0.0179
# 313/313 - 0s - loss: 0.0176
# test mse: 0.01762

# %% [markdown]
# Shallow non-linear autoencoder test mse:
# 0.00426
#
# I tried both tanh, sigmoid and ReLU. I chose sigmoid because it is the one that worked better. As we can see the results are similar although non-linear activation function works better, in fact the background is less blurred.

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.4: Deep Autoencoder
# **[TO COMPLETE]**: Define a deep version of the Autoeancoder defined above. The autoencoder has to use at least 5 layers. The model will use $n$ layers for encoding, and n-1 for decoding. The layers sizes of the encoding part decrease at each layer (i.e. 784->128->64, where 64 is the encoding dim). The decoding part layers dimensions progression turns out to be mirrored (i.e 128->784, the resulting overall structure recalls an hourglass).
# Similarly than what we did above, print the model summary, the loss curves during the training, the achieved loss on the test set, and some input images with the corresponding decoding.

# %%
input_img = tf.keras.layers.Input(shape=(784,))

#Encoding
encoded = tf.keras.layers.Dense(256, activation='relu')(input_img)
encoded = tf.keras.layers.Dense(128, activation='relu')(encoded)
encoded = tf.keras.layers.Dense(64, activation='relu')(encoded)

#Decoding
decoded = tf.keras.layers.Dense(128, activation='relu')(encoded)
decoded = tf.keras.layers.Dense(256, activation='relu')(decoded)
decoded = tf.keras.layers.Dense(784, activation='sigmoid')(decoded)

autoencoder = tf.keras.models.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='mse')

# %%
autoencoder.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               200960
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_9 (Dense)              (None, 784)               201488
# =================================================================
# Total params: 484,944
# Trainable params: 484,944
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = autoencoder.fit(x_train, x_train, epochs=30, batch_size=256, shuffle=True, validation_data=(x_valid, x_valid))
# Out:
# Epoch 1/30
# 196/196 [==============================] - 4s 17ms/step - loss: 0.0595 - val_loss: 0.0308
# Epoch 2/30
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0241 - val_loss: 0.0200
# Epoch 3/30
# 196/196 [==============================] - 3s 15ms/step - loss: 0.0179 - val_loss: 0.0158
# Epoch 4/30
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0148 - val_loss: 0.0136
# Epoch 5/30
# 196/196 [==============================] - 3s 15ms/step - loss: 0.0130 - val_loss: 0.0124
# Epoch 6/30
# 196/196 [==============================] - 3s 15ms/step - loss: 0.0118 - val_loss: 0.0113
# Epoch 7/30
# 196/196 [==============================] - 3s 15ms/step - loss: 0.0110 - val_loss: 0.0107
# Epoch 8/30
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0103 - val_loss: 0.0100
# Epoch 9/30
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0096 - val_loss: 0.0094
# Epoch 10/30
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0092 - val_loss: 0.0091
# Epoch 11/30
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0087 - val_loss: 0.0086
# Epoch 12/30
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0084 - val_loss: 0.0082
# Epoch 13/30
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0080 - val_loss: 0.0080
# Epoch 14/30
# 196/196 [==============================] - 3s 15ms/step - loss: 0.0078 - val_loss: 0.0076
# Epoch 15/30
# 196/196 [==============================] - 3s 15ms/step - loss: 0.0075 - val_loss: 0.0074
# Epoch 16/30
# 196/196 [==============================] - 3s 15ms/step - loss: 0.0072 - val_loss: 0.0073
# Epoch 17/30
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0070 - val_loss: 0.0071
# Epoch 18/30
# 196/196 [==============================] - 3s 15ms/step - loss: 0.0068 - val_loss: 0.0067
# Epoch 19/30
# 196/196 [==============================] - 3s 15ms/step - loss: 0.0066 - val_loss: 0.0067
# Epoch 20/30
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 21/30
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0063 - val_loss: 0.0063
# Epoch 22/30
# 196/196 [==============================] - 3s 15ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 23/30
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 24/30
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 25/30
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0058 - val_loss: 0.0062
# Epoch 26/30
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 27/30
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0056 - val_loss: 0.0058
# Epoch 28/30
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0055 - val_loss: 0.0057
# Epoch 29/30
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0054 - val_loss: 0.0056
# Epoch 30/30
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0053 - val_loss: 0.0055

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test, x_test, verbose=2)
print("test mse: %.5f" % (scores))
# Out:
# 313/313 - 1s - loss: 0.0053
# test mse: 0.00530

# %%
decoded_imgs = autoencoder.predict(x_test)

plot_img(10, x_test, decoded_imgs)

# %% [markdown]
# ## [TO COMPLETE] Exercise 5.5: Denoising Autoencoder
#
# Let's now use a shallow autoencoder to denoise the input data.
# Firstly, define a noisy input by adding some noise to our input data. We define a noise factor that can be used to modify the amount of noise to add to the input data. Check how much it influences the denoising capability of the autoencoder.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

x_valid, y_valid = x_train[:10000],y_train[:10000]
x_train, y_train = x_train[10000:],y_train[10000:]

noise_factor = 0.3

x_train_noisy = x_train + noise_factor + np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor + np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
x_valid_noisy = x_valid + noise_factor + np.random.normal(loc=0.0, scale=1.0, size=x_valid.shape)


x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)
x_valid_noisy = np.clip(x_valid_noisy, 0., 1.)

# %% [markdown]
# Plot some noisy inputs.

# %%
# here's what the noisy digits look like
n = 10
plt.figure(figsize=(20, 2))
for i in range(n):
    ax = plt.subplot(1, n, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# **[TO COMPLETE]** Define a shallow autoencoder able to compute a de-noised version of the input (obtained by unsing a noise_factor >= 0.3).

# %%
input_img = tf.keras.layers.Input(shape=(784,))
#Define the encoder...
encoded = tf.keras.layers.Dense(ENCODING_DIM, activation='relu')(input_img)

#...and the decoder...
decoded = tf.keras.layers.Dense(784, activation='sigmoid')(encoded)

#and finally the autoencoder
autoencoder = tf.keras.models.Model(input_img, decoded)

#Finally, let's call the compile method
autoencoder.compile(optimizer='adam', loss='mse')

# %%
autoencoder.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense_10 (Dense)             (None, 120)               94200
# _________________________________________________________________
# dense_11 (Dense)             (None, 784)               94864
# =================================================================
# Total params: 189,064
# Trainable params: 189,064
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **[TO COMPLETE]** Train the model by passing the noisy input and the clean target.

# %%
history = autoencoder.fit(x_train_noisy, x_train, epochs=30 ,batch_size=128, shuffle=True, validation_data=(x_valid_noisy, x_valid))#[TO COMPLETE]
# Out:
# Epoch 1/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0618 - val_loss: 0.0471
# Epoch 2/30
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0440 - val_loss: 0.0414
# Epoch 3/30
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0401 - val_loss: 0.0391
# Epoch 4/30
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0382 - val_loss: 0.0378
# Epoch 5/30
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0371 - val_loss: 0.0372
# Epoch 6/30
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0364 - val_loss: 0.0368
# Epoch 7/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0359 - val_loss: 0.0363
# Epoch 8/30
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0355 - val_loss: 0.0362
# Epoch 9/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0351 - val_loss: 0.0358
# Epoch 10/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0348 - val_loss: 0.0357
# Epoch 11/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0346 - val_loss: 0.0356
# Epoch 12/30
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0344 - val_loss: 0.0354
# Epoch 13/30
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0341 - val_loss: 0.0354
# Epoch 14/30
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0339 - val_loss: 0.0351
# Epoch 15/30
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0337 - val_loss: 0.0350
# Epoch 16/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0335 - val_loss: 0.0348
# Epoch 17/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0333 - val_loss: 0.0348
# Epoch 18/30
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0332 - val_loss: 0.0346
# Epoch 19/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0330 - val_loss: 0.0347
# Epoch 20/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0329 - val_loss: 0.0344
# Epoch 21/30
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0327 - val_loss: 0.0343
# Epoch 22/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0326 - val_loss: 0.0343
# Epoch 23/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0325 - val_loss: 0.0342
# Epoch 24/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0324 - val_loss: 0.0341
# Epoch 25/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0323 - val_loss: 0.0339
# Epoch 26/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0322 - val_loss: 0.0340
# Epoch 27/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0321 - val_loss: 0.0340
# Epoch 28/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0320 - val_loss: 0.0340
# Epoch 29/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0319 - val_loss: 0.0339
# Epoch 30/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0318 - val_loss: 0.0337

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test_noisy, x_test, verbose=2)
print("test mse: %.5f" % (scores))
# Out:
# 313/313 - 0s - loss: 0.0334
# test mse: 0.03339

# %% [markdown]
# **[TO COMPLETE]** Check the result by plotting some input images and the corresponding denoised outputs.

# %%
decoded_imgs = autoencoder.predict(x_test_noisy)

plot_img(10, x_test_noisy, decoded_imgs)

# %% [markdown]
# ## Exercise 5.6: Linear Autoencoder for sequences
#
# Let's define a linear autoencoder for sequences. In this case, as dataset, we will use the IMDB dataset (already presented in HW4). To have a model that can be trained and tested in a reasonable time (and that works also with the memory limitation that we have in Colab), we will limit the number of training samples and test samples.

# %%
num_words = 100
(X_train, _), (X_test, _) = keras.datasets.imdb.load_data(num_words=num_words)

X_train=X_train[:10000]

(X_valid, X_test) = X_test[:1250], X_test[-1250:]

word_index = keras.datasets.imdb.get_word_index()

reverse_index = {word_id + 3: word for word, word_id in word_index.items()}
reverse_index[0] = "<pad>" # padding
reverse_index[1] = "<sos>" # start of sequence
reverse_index[2] = "<oov>" # out-of-vocabulary
reverse_index[3] = "<unk>" # unknown

def decode_review(word_ids):
    return " ".join([reverse_index.get(word_id, "<err>") for word_id in word_ids])


maxlen = 90
X_train_trim = keras.preprocessing.sequence.pad_sequences(X_train, maxlen=maxlen)
X_test_trim = keras.preprocessing.sequence.pad_sequences(X_test, maxlen=maxlen)
X_valid_trim = keras.preprocessing.sequence.pad_sequences(X_valid, maxlen=maxlen)
# Out:
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:155: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:156: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %% [markdown]
# In this case, we want to use as input/target a one-hot representation for each word. To convert the index representation provided by IMDB dataset loader we use the to_categorical method to transform them in the corresponding one hot representation.

# %%
from tensorflow.keras.utils import to_categorical


X_train_one_hot=to_categorical(X_train_trim)
X_test_one_hot=to_categorical(X_test_trim)
X_valid_one_hot=to_categorical(X_valid_trim)

# %% [markdown]
# Define a linear shallow autoencoder for sequences. The structure will be similar to the model defined in Exercise 5.2, while the used encoding layer is defined by using tf.keras.layers.SimpleRNN. Note that it uses linear activations. The decoding layer exploits [tf.keras.layers.TimeDistributed](https://www.tensorflow.org/api_docs/python/tf/keras/layers/TimeDistributed) that allows using the same dense cell at each time step of the sequence.

# %%
inputs = tf.keras.layers.Input(shape=(maxlen, num_words))
encoded = tf.keras.layers.SimpleRNN(50, return_sequences=True, activation='linear')(inputs)

decoded = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(num_words, activation='linear'))(encoded)

sequence_autoencoder = tf.keras.models.Model(inputs, decoded)
encoder = tf.keras.models.Model(inputs, encoded)

sequence_autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=["CategoricalAccuracy"])

sequence_autoencoder.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 90, 100)]         0
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, 90, 50)            7550
# _________________________________________________________________
# time_distributed (TimeDistri (None, 90, 100)           5100
# =================================================================
# Total params: 12,650
# Trainable params: 12,650
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = sequence_autoencoder.fit(X_train_one_hot, X_train_one_hot, epochs=50, batch_size=128, shuffle=True, validation_data=(X_valid_one_hot, X_valid_one_hot))
# Out:
# Epoch 1/50
# 79/79 [==============================] - 6s 71ms/step - loss: 0.1917 - categorical_accuracy: 0.1612 - val_loss: 0.0884 - val_categorical_accuracy: 0.4392
# Epoch 2/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0710 - categorical_accuracy: 0.4818 - val_loss: 0.0641 - val_categorical_accuracy: 0.4960
# Epoch 3/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0593 - categorical_accuracy: 0.5266 - val_loss: 0.0572 - val_categorical_accuracy: 0.5452
# Epoch 4/50
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0521 - categorical_accuracy: 0.5626 - val_loss: 0.0483 - val_categorical_accuracy: 0.5902
# Epoch 5/50
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0452 - categorical_accuracy: 0.6099 - val_loss: 0.0423 - val_categorical_accuracy: 0.6116
# Epoch 6/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0390 - categorical_accuracy: 0.6307 - val_loss: 0.0374 - val_categorical_accuracy: 0.6428
# Epoch 7/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0347 - categorical_accuracy: 0.6698 - val_loss: 0.0336 - val_categorical_accuracy: 0.6920
# Epoch 8/50
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0314 - categorical_accuracy: 0.6983 - val_loss: 0.0304 - val_categorical_accuracy: 0.7097
# Epoch 9/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0289 - categorical_accuracy: 0.7417 - val_loss: 0.0281 - val_categorical_accuracy: 0.7471
# Epoch 10/50
# 79/79 [==============================] - 5s 69ms/step - loss: 0.0267 - categorical_accuracy: 0.7614 - val_loss: 0.0262 - val_categorical_accuracy: 0.7739
# Epoch 11/50
# 79/79 [==============================] - 5s 70ms/step - loss: 0.0259 - categorical_accuracy: 0.7696 - val_loss: 0.0245 - val_categorical_accuracy: 0.8042
# Epoch 12/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0232 - categorical_accuracy: 0.8160 - val_loss: 0.0227 - val_categorical_accuracy: 0.8248
# Epoch 13/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0217 - categorical_accuracy: 0.8358 - val_loss: 0.0214 - val_categorical_accuracy: 0.8415
# Epoch 14/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0206 - categorical_accuracy: 0.8527 - val_loss: 0.0206 - val_categorical_accuracy: 0.8591
# Epoch 15/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0200 - categorical_accuracy: 0.8694 - val_loss: 0.0200 - val_categorical_accuracy: 0.8704
# Epoch 16/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0194 - categorical_accuracy: 0.8785 - val_loss: 0.0194 - val_categorical_accuracy: 0.8801
# Epoch 17/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0189 - categorical_accuracy: 0.8869 - val_loss: 0.0190 - val_categorical_accuracy: 0.8893
# Epoch 18/50
# 79/79 [==============================] - 5s 69ms/step - loss: 0.0185 - categorical_accuracy: 0.8939 - val_loss: 0.0185 - val_categorical_accuracy: 0.8936
# Epoch 19/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0179 - categorical_accuracy: 0.8993 - val_loss: 0.0180 - val_categorical_accuracy: 0.8997
# Epoch 20/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0175 - categorical_accuracy: 0.9040 - val_loss: 0.0175 - val_categorical_accuracy: 0.9041
# Epoch 21/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0169 - categorical_accuracy: 0.9084 - val_loss: 0.0171 - val_categorical_accuracy: 0.9077
# Epoch 22/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0166 - categorical_accuracy: 0.9112 - val_loss: 0.0168 - val_categorical_accuracy: 0.9104
# Epoch 23/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0164 - categorical_accuracy: 0.9136 - val_loss: 0.0166 - val_categorical_accuracy: 0.9126
# Epoch 24/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0161 - categorical_accuracy: 0.9156 - val_loss: 0.0164 - val_categorical_accuracy: 0.9140
# Epoch 25/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0159 - categorical_accuracy: 0.9175 - val_loss: 0.0160 - val_categorical_accuracy: 0.9162
# Epoch 26/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0155 - categorical_accuracy: 0.9198 - val_loss: 0.0159 - val_categorical_accuracy: 0.9179
# Epoch 27/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0154 - categorical_accuracy: 0.9209 - val_loss: 0.0155 - val_categorical_accuracy: 0.9200
# Epoch 28/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0150 - categorical_accuracy: 0.9224 - val_loss: 0.0153 - val_categorical_accuracy: 0.9209
# Epoch 29/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0149 - categorical_accuracy: 0.9230 - val_loss: 0.0151 - val_categorical_accuracy: 0.9216
# Epoch 30/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0147 - categorical_accuracy: 0.9235 - val_loss: 0.0149 - val_categorical_accuracy: 0.9221
# Epoch 31/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0145 - categorical_accuracy: 0.9240 - val_loss: 0.0147 - val_categorical_accuracy: 0.9226
# Epoch 32/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0143 - categorical_accuracy: 0.9244 - val_loss: 0.0146 - val_categorical_accuracy: 0.9229
# Epoch 33/50
# 79/79 [==============================] - 5s 69ms/step - loss: 0.0141 - categorical_accuracy: 0.9257 - val_loss: 0.0143 - val_categorical_accuracy: 0.9242
# Epoch 34/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0138 - categorical_accuracy: 0.9266 - val_loss: 0.0141 - val_categorical_accuracy: 0.9248
# Epoch 35/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0137 - categorical_accuracy: 0.9270 - val_loss: 0.0139 - val_categorical_accuracy: 0.9253
# Epoch 36/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0135 - categorical_accuracy: 0.9273 - val_loss: 0.0138 - val_categorical_accuracy: 0.9254
# Epoch 37/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0134 - categorical_accuracy: 0.9276 - val_loss: 0.0136 - val_categorical_accuracy: 0.9257
# Epoch 38/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0132 - categorical_accuracy: 0.9277 - val_loss: 0.0135 - val_categorical_accuracy: 0.9259
# Epoch 39/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0131 - categorical_accuracy: 0.9279 - val_loss: 0.0134 - val_categorical_accuracy: 0.9261
# Epoch 40/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0130 - categorical_accuracy: 0.9280 - val_loss: 0.0132 - val_categorical_accuracy: 0.9262
# Epoch 41/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0129 - categorical_accuracy: 0.9282 - val_loss: 0.0131 - val_categorical_accuracy: 0.9263
# Epoch 42/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0127 - categorical_accuracy: 0.9283 - val_loss: 0.0130 - val_categorical_accuracy: 0.9264
# Epoch 43/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0126 - categorical_accuracy: 0.9284 - val_loss: 0.0129 - val_categorical_accuracy: 0.9265
# Epoch 44/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0125 - categorical_accuracy: 0.9284 - val_loss: 0.0128 - val_categorical_accuracy: 0.9266
# Epoch 45/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0124 - categorical_accuracy: 0.9286 - val_loss: 0.0127 - val_categorical_accuracy: 0.9267
# Epoch 46/50
# 79/79 [==============================] - 5s 69ms/step - loss: 0.0123 - categorical_accuracy: 0.9286 - val_loss: 0.0126 - val_categorical_accuracy: 0.9268
# Epoch 47/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0122 - categorical_accuracy: 0.9287 - val_loss: 0.0125 - val_categorical_accuracy: 0.9269
# Epoch 48/50
# 79/79 [==============================] - 5s 69ms/step - loss: 0.0121 - categorical_accuracy: 0.9287 - val_loss: 0.0124 - val_categorical_accuracy: 0.9270
# Epoch 49/50
# 79/79 [==============================] - 5s 69ms/step - loss: 0.0121 - categorical_accuracy: 0.9288 - val_loss: 0.0123 - val_categorical_accuracy: 0.9271
# Epoch 50/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0120 - categorical_accuracy: 0.9288 - val_loss: 0.0122 - val_categorical_accuracy: 0.9271

# %% [markdown]
# Let's plot the accuracy and the loss trends and check the reconstruction capability of the model by plotting the reconstruction of a test sample

# %%
def plot_categorical_accuracy(history):
  plt.figure(figsize=(10,6))
  plt.plot(history.epoch,history.history['categorical_accuracy'])
  plt.plot(history.epoch,history.history['val_categorical_accuracy'])
  plt.title('accuracy')

plot_loss(history)

plot_categorical_accuracy(history)

scores = sequence_autoencoder.evaluate(X_test_one_hot, X_test_one_hot, verbose=2)
print("%s: %.2f%%" % (sequence_autoencoder.metrics_names[1], scores[1]*100))
# Out:
# 40/40 - 0s - loss: 0.0120 - categorical_accuracy: 0.9286
# categorical_accuracy: 92.86%

# %%
decoded_text = sequence_autoencoder.predict(X_test_one_hot)
decode_index= np.argmax(decoded_text[500], axis=1)
input_text= np.argmax(X_test_one_hot[500], axis=1)

print(decode_review(input_text))
print(decode_review(decode_index))
# Out:
# than a <oov> <oov> that are <oov> in all of that time but that <oov> the <oov> is <oov> a very <oov> film in just about <oov> <oov> <oov> <oov> as some other <oov> have <oov> out it <oov> like <oov> <oov> of the film are <oov> <oov> there <oov> other <oov> <oov> <oov> are <oov> <oov> in the <oov> <oov> this is a really bad film that <oov> <oov> <oov> than its <oov> of <oov> <oov> i <oov> it <oov> out of <oov> and i <oov> <oov> very <oov>
# way a <oov> <oov> that <oov> <oov> in all of that i to that <oov> the <oov> is <oov> a very <oov> film in just about <oov> <oov> <oov> <oov> as some so <oov> have <oov> out it <oov> film <oov> <oov> of the film you <oov> <oov> on <oov> at <oov> <oov> <oov> on <oov> <oov> in the <oov> <oov> this is a i bad film that <oov> <oov> <oov> that i <oov> of <oov> <oov> i <oov> it <oov> out of <oov> and i <oov> <oov> very <oov>

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.7: Non-Linear Autoencoder for sequences
# **[TO COMPLETE]**: Replicate the code of the above exercise, but instead of using a simpleRNN with linear activation do the same  using  non-linear activation functions and using an LSTM layer. Choose the most appropriate non-linear function, and motivate your choice. Then discuss the results in relation to those obtained by the linear autoencoder for sequences.
#
# Hint: using a non-linear function also in the dense layer after the RNN/LSTM one will help to obtain better results. The choice of this function should be based on the type of output data.

# %%
inputs = tf.keras.layers.Input(shape=(maxlen, num_words))
encoded = tf.keras.layers.LSTM(50, return_sequences=True, activation='sigmoid')(inputs)

decoded = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(num_words, activation='softmax'))(encoded)

sequence_autoencoder = tf.keras.models.Model(inputs, decoded)
encoder = tf.keras.models.Model(inputs, encoded)

sequence_autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=["CategoricalAccuracy"])

sequence_autoencoder.summary()

history = sequence_autoencoder.fit(X_train_one_hot, X_train_one_hot, epochs=50, batch_size=128, shuffle=True, validation_data=(X_valid_one_hot, X_valid_one_hot))

plot_loss(history)

plot_categorical_accuracy(history)

scores = sequence_autoencoder.evaluate(X_test_one_hot, X_test_one_hot, verbose=2)
print("%s: %.2f%%" % (sequence_autoencoder.metrics_names[1], scores[1]*100))

decoded_text = sequence_autoencoder.predict(X_test_one_hot)
decode_index= np.argmax(decoded_text[500], axis=1)
input_text= np.argmax(X_test_one_hot[500], axis=1)

print(decode_review(input_text))
print(decode_review(decode_index))
# Out:
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 90, 100)]         0
# _________________________________________________________________
# lstm (LSTM)                  (None, 90, 50)            30200
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 90, 100)           5100
# =================================================================
# Total params: 35,300
# Trainable params: 35,300
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 79/79 [==============================] - 10s 117ms/step - loss: 0.0417 - categorical_accuracy: 0.4530 - val_loss: 0.0370 - val_categorical_accuracy: 0.4614
# Epoch 2/50
# 79/79 [==============================] - 9s 114ms/step - loss: 0.0361 - categorical_accuracy: 0.4710 - val_loss: 0.0359 - val_categorical_accuracy: 0.4614
# Epoch 3/50
# 79/79 [==============================] - 9s 114ms/step - loss: 0.0344 - categorical_accuracy: 0.4710 - val_loss: 0.0335 - val_categorical_accuracy: 0.4614
# Epoch 4/50
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0314 - categorical_accuracy: 0.4710 - val_loss: 0.0300 - val_categorical_accuracy: 0.4614
# Epoch 5/50
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0275 - categorical_accuracy: 0.4710 - val_loss: 0.0257 - val_categorical_accuracy: 0.4614
# Epoch 6/50
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0231 - categorical_accuracy: 0.6062 - val_loss: 0.0210 - val_categorical_accuracy: 0.7337
# Epoch 7/50
# 79/79 [==============================] - 9s 115ms/step - loss: 0.0185 - categorical_accuracy: 0.7552 - val_loss: 0.0167 - val_categorical_accuracy: 0.7651
# Epoch 8/50
# 79/79 [==============================] - 9s 117ms/step - loss: 0.0147 - categorical_accuracy: 0.7943 - val_loss: 0.0134 - val_categorical_accuracy: 0.8109
# Epoch 9/50
# 79/79 [==============================] - 9s 117ms/step - loss: 0.0118 - categorical_accuracy: 0.8254 - val_loss: 0.0108 - val_categorical_accuracy: 0.8295
# Epoch 10/50
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0096 - categorical_accuracy: 0.8485 - val_loss: 0.0088 - val_categorical_accuracy: 0.8601
# Epoch 11/50
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0078 - categorical_accuracy: 0.8884 - val_loss: 0.0071 - val_categorical_accuracy: 0.9014
# Epoch 12/50
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0062 - categorical_accuracy: 0.9127 - val_loss: 0.0057 - val_categorical_accuracy: 0.9191
# Epoch 13/50
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0049 - categorical_accuracy: 0.9307 - val_loss: 0.0045 - val_categorical_accuracy: 0.9421
# Epoch 14/50
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0039 - categorical_accuracy: 0.9548 - val_loss: 0.0035 - val_categorical_accuracy: 0.9638
# Epoch 15/50
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0030 - categorical_accuracy: 0.9720 - val_loss: 0.0027 - val_categorical_accuracy: 0.9794
# Epoch 16/50
# 79/79 [==============================] - 9s 113ms/step - loss: 0.0023 - categorical_accuracy: 0.9862 - val_loss: 0.0020 - val_categorical_accuracy: 0.9910
# Epoch 17/50
# 79/79 [==============================] - 9s 115ms/step - loss: 0.0017 - categorical_accuracy: 0.9936 - val_loss: 0.0015 - val_categorical_accuracy: 0.9951
# Epoch 18/50
# 79/79 [==============================] - 9s 115ms/step - loss: 0.0013 - categorical_accuracy: 0.9975 - val_loss: 0.0011 - val_categorical_accuracy: 0.9986
# Epoch 19/50
# 79/79 [==============================] - 9s 115ms/step - loss: 9.5514e-04 - categorical_accuracy: 0.9989 - val_loss: 8.4744e-04 - val_categorical_accuracy: 0.9991
# Epoch 20/50
# 79/79 [==============================] - 9s 114ms/step - loss: 7.2979e-04 - categorical_accuracy: 0.9998 - val_loss: 6.5530e-04 - val_categorical_accuracy: 1.0000
# Epoch 21/50
# 79/79 [==============================] - 9s 114ms/step - loss: 5.7165e-04 - categorical_accuracy: 1.0000 - val_loss: 5.2018e-04 - val_categorical_accuracy: 1.0000
# Epoch 22/50
# 79/79 [==============================] - 9s 117ms/step - loss: 4.5929e-04 - categorical_accuracy: 1.0000 - val_loss: 4.2301e-04 - val_categorical_accuracy: 1.0000
# Epoch 23/50
# 79/79 [==============================] - 9s 119ms/step - loss: 3.7764e-04 - categorical_accuracy: 1.0000 - val_loss: 3.5136e-04 - val_categorical_accuracy: 1.0000
# Epoch 24/50
# 79/79 [==============================] - 9s 118ms/step - loss: 3.1679e-04 - categorical_accuracy: 1.0000 - val_loss: 2.9734e-04 - val_categorical_accuracy: 1.0000
# Epoch 25/50
# 79/79 [==============================] - 9s 117ms/step - loss: 2.7041e-04 - categorical_accuracy: 1.0000 - val_loss: 2.5576e-04 - val_categorical_accuracy: 1.0000
# Epoch 26/50
# 79/79 [==============================] - 9s 116ms/step - loss: 2.3419e-04 - categorical_accuracy: 1.0000 - val_loss: 2.2283e-04 - val_categorical_accuracy: 1.0000
# Epoch 27/50
# 79/79 [==============================] - 9s 115ms/step - loss: 2.0529e-04 - categorical_accuracy: 1.0000 - val_loss: 1.9630e-04 - val_categorical_accuracy: 1.0000
# Epoch 28/50
# 79/79 [==============================] - 9s 116ms/step - loss: 1.8181e-04 - categorical_accuracy: 1.0000 - val_loss: 1.7460e-04 - val_categorical_accuracy: 1.0000
# Epoch 29/50
# 79/79 [==============================] - 9s 115ms/step - loss: 1.6240e-04 - categorical_accuracy: 1.0000 - val_loss: 1.5648e-04 - val_categorical_accuracy: 1.0000
# Epoch 30/50
# 79/79 [==============================] - 9s 115ms/step - loss: 1.4612e-04 - categorical_accuracy: 1.0000 - val_loss: 1.4119e-04 - val_categorical_accuracy: 1.0000
# Epoch 31/50
# 79/79 [==============================] - 9s 117ms/step - loss: 1.3227e-04 - categorical_accuracy: 1.0000 - val_loss: 1.2812e-04 - val_categorical_accuracy: 1.0000
# Epoch 32/50
# 79/79 [==============================] - 9s 117ms/step - loss: 1.2037e-04 - categorical_accuracy: 1.0000 - val_loss: 1.1685e-04 - val_categorical_accuracy: 1.0000
# Epoch 33/50
# 79/79 [==============================] - 9s 116ms/step - loss: 1.1005e-04 - categorical_accuracy: 1.0000 - val_loss: 1.0702e-04 - val_categorical_accuracy: 1.0000
# Epoch 34/50
# 79/79 [==============================] - 9s 116ms/step - loss: 1.0101e-04 - categorical_accuracy: 1.0000 - val_loss: 9.8383e-05 - val_categorical_accuracy: 1.0000
# Epoch 35/50
# 79/79 [==============================] - 9s 117ms/step - loss: 9.3039e-05 - categorical_accuracy: 1.0000 - val_loss: 9.0731e-05 - val_categorical_accuracy: 1.0000
# Epoch 36/50
# 79/79 [==============================] - 9s 117ms/step - loss: 8.5962e-05 - categorical_accuracy: 1.0000 - val_loss: 8.3934e-05 - val_categorical_accuracy: 1.0000
# Epoch 37/50
# 79/79 [==============================] - 9s 117ms/step - loss: 7.9661e-05 - categorical_accuracy: 1.0000 - val_loss: 7.7864e-05 - val_categorical_accuracy: 1.0000
# Epoch 38/50
# 79/79 [==============================] - 9s 115ms/step - loss: 7.4011e-05 - categorical_accuracy: 1.0000 - val_loss: 7.2410e-05 - val_categorical_accuracy: 1.0000
# Epoch 39/50
# 79/79 [==============================] - 9s 118ms/step - loss: 6.8921e-05 - categorical_accuracy: 1.0000 - val_loss: 6.7481e-05 - val_categorical_accuracy: 1.0000
# Epoch 40/50
# 79/79 [==============================] - 9s 116ms/step - loss: 6.4314e-05 - categorical_accuracy: 1.0000 - val_loss: 6.3016e-05 - val_categorical_accuracy: 1.0000
# Epoch 41/50
# 79/79 [==============================] - 9s 116ms/step - loss: 6.0126e-05 - categorical_accuracy: 1.0000 - val_loss: 5.8951e-05 - val_categorical_accuracy: 1.0000
# Epoch 42/50
# 79/79 [==============================] - 9s 118ms/step - loss: 5.6307e-05 - categorical_accuracy: 1.0000 - val_loss: 5.5240e-05 - val_categorical_accuracy: 1.0000
# Epoch 43/50
# 79/79 [==============================] - 9s 118ms/step - loss: 5.2823e-05 - categorical_accuracy: 1.0000 - val_loss: 5.1854e-05 - val_categorical_accuracy: 1.0000
# Epoch 44/50
# 79/79 [==============================] - 9s 116ms/step - loss: 4.9626e-05 - categorical_accuracy: 1.0000 - val_loss: 4.8740e-05 - val_categorical_accuracy: 1.0000
# Epoch 45/50
# 79/79 [==============================] - 9s 117ms/step - loss: 4.6686e-05 - categorical_accuracy: 1.0000 - val_loss: 4.5870e-05 - val_categorical_accuracy: 1.0000
# Epoch 46/50
# 79/79 [==============================] - 9s 116ms/step - loss: 4.3975e-05 - categorical_accuracy: 1.0000 - val_loss: 4.3226e-05 - val_categorical_accuracy: 1.0000
# Epoch 47/50
# 79/79 [==============================] - 9s 116ms/step - loss: 4.1470e-05 - categorical_accuracy: 1.0000 - val_loss: 4.0779e-05 - val_categorical_accuracy: 1.0000
# Epoch 48/50
# 79/79 [==============================] - 9s 116ms/step - loss: 3.9154e-05 - categorical_accuracy: 1.0000 - val_loss: 3.8514e-05 - val_categorical_accuracy: 1.0000
# Epoch 49/50
# 79/79 [==============================] - 9s 116ms/step - loss: 3.7004e-05 - categorical_accuracy: 1.0000 - val_loss: 3.6411e-05 - val_categorical_accuracy: 1.0000
# Epoch 50/50
# 79/79 [==============================] - 9s 117ms/step - loss: 3.5006e-05 - categorical_accuracy: 1.0000 - val_loss: 3.4456e-05 - val_categorical_accuracy: 1.0000
# 40/40 - 1s - loss: 3.3768e-05 - categorical_accuracy: 1.0000
# categorical_accuracy: 100.00%
# than a <oov> <oov> that are <oov> in all of that time but that <oov> the <oov> is <oov> a very <oov> film in just about <oov> <oov> <oov> <oov> as some other <oov> have <oov> out it <oov> like <oov> <oov> of the film are <oov> <oov> there <oov> other <oov> <oov> <oov> are <oov> <oov> in the <oov> <oov> this is a really bad film that <oov> <oov> <oov> than its <oov> of <oov> <oov> i <oov> it <oov> out of <oov> and i <oov> <oov> very <oov>
# than a <oov> <oov> that are <oov> in all of that time but that <oov> the <oov> is <oov> a very <oov> film in just about <oov> <oov> <oov> <oov> as some other <oov> have <oov> out it <oov> like <oov> <oov> of the film are <oov> <oov> there <oov> other <oov> <oov> <oov> are <oov> <oov> in the <oov> <oov> this is a really bad film that <oov> <oov> <oov> than its <oov> of <oov> <oov> i <oov> it <oov> out of <oov> and i <oov> <oov> very <oov>

# %% [markdown]
# Since it is a classification problem softax is the best activation function on the last layer.
#
# With respect to the linear model this one works better but it is more complex: the parameters in the linear model are 12,650 while the parameters in this model are 35,300.
